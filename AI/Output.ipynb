# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(pd.read_csv('output.csv'), columns=['X', 'Y', 'Predict'])

print(df)
plt.plot(df.Y)
plt.plot(df.Predict)
plt.ylabel('some numbers')
plt.show()
# Out:
#        X     Y  Predict
# 0   0.00  0.00     0.05
# 1   0.06  0.06     0.05
# 2   0.13  0.13     0.12
# 3   0.19  0.19     0.21
# 4   0.25  0.25     0.28
# ..   ...   ...      ...
# 95 -2.83 -0.31    -0.34
# 96 -2.89 -0.25    -0.35
# 97 -2.95 -0.19    -0.36
# 98 -3.01 -0.13    -0.36
# 99 -3.08 -0.06    -0.37
#
# [100 rows x 3 columns]
